# %%
import os
import sys
import traceback
from mimetypes import guess_extension
from time import time, sleep
from urllib.request import urlopen, Request
from urllib.parse import quote
from bs4 import BeautifulSoup

MY_EMAIL_ADDR = ''

class Fetcher:
    def __init__(self, ua=''):
        self.ua = ua

    def fetch_img_direct(self, url):
        """
        yahoo画像検索画面に表示されている画像のbyte情報を抽出します。
        引数:
            url: yahoo画像検索画面のurlです。

        返り値:
            img_b_content: ウェブサイトリソースのbyteコードのリストです。
            mime: CONTENT_TYPEにより指定されている拡張子です。
        """
        req = Request(url, headers={'User-Agent': self.ua})
        try:
            with urlopen(req, timeout=3) as p:
                page_b_content = p.read()
                structured_page = BeautifulSoup(page_b_content.decode('UTF-8'), 'html.parser')
                img_link_elems = structured_page.find_all('img')
                img_urls = [e.get('src') for e in img_link_elems if e.get('src').startswith('http')]
                img_urls = list(set(img_urls)) #なぜset化しているのかは不明
        except:
            sys.stderr.write('Error in fetching {}\n'.format(url))
            sys.stderr.write(traceback.format_exc())
            return None, None

        img_b_content = []
        mime = []
        for i, img_url in enumerate(img_urls):
            req1 = Request(img_url, headers={'User-Agent': self.ua})
            try:
                with urlopen(req1, timeout=3) as p:
                    img_b_content.append(p.read())
                    mime.append(p.getheader('Content-Type'))
            except:
                sys.stderr.write('Error in fetching {}\n'.format(img_url))
                sys.stderr.write(traceback.format_exc())
                continue

        return img_b_content, mime

fetcher = Fetcher(MY_EMAIL_ADDR)



def url_brancher(word):
    """
    yahoo画像検索画面のurlを、検索条件の組み合わせの数だけ取得します。

    引数:
        word : 検索語です。

    返り値:
        urllist : yahoo画像検索画面のurlのリストです。
    """
    constant = "https://search.yahoo.co.jp/image/search?p={}&ei=UTF-8&".format(quote(word))

    values = [str(20*i+1) for i in range(30)]
    """
    values = [\
    ["", "small", "medium", "large", "wallpaper", "widewallpaper"],\
    ["", "red", "orange", "yellow", "green", "teal", "blue", "purple", "pink", "white", "gray", "black", "brown"],\
    ["", "face", "photo", "clipart", "lineart"]\
    ]
    """
    urllist = []

    for b in values:
        urllist.append(constant+"b="+b)
    return urllist



def main(word):
    """
    Fetchにより取得された情報をもとに画像ファイルを保存します。

    引数:
    word: 検索語です。

    返り値:
    """
    data_dir = './data/'
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    yahoo_url_list = url_brancher(word)

    for i, yahoo_url in enumerate(yahoo_url_list):
        sleep(0.1)
        img, mime = fetcher.fetch_img_direct(yahoo_url)
        if not mime or not img:
            print('Error in fetching {}\n'.format(yahoo_url))
            continue

        for j, img_url in enumerate(img):
            ext = guess_extension(mime[j].split(';')[0])
            if ext in ('.jpe', '.jpeg'):
                ext = '.jpg'
            if not ext:
                print('Error in fetching {}\n'.format(img_url))
                continue

            result_file = os.path.join(data_dir, str(i) + str(j)+ ext)
            with open(result_file, mode='wb') as f:
                f.write(img_url)
            print('fetched', str(i) + str(j) + ext)



if __name__ == '__main__':
    word = "鬼滅の刃+漫画+炭治郎"
    main(word)
# Out:
# fetched 00.jpg
aconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\msy-o\Anaconda3\lib\urllib\request.py", line 525, in open
#     response = self._open(req, data)
#   File "C:\Users\msy-o\Anaconda3\lib\urllib\request.py", line 543, in _open
#     '_open', req)
#   File "C:\Users\msy-o\Anaconda3\lib\urllib\request.py", line 503, in _call_chain
#     result = func(*args)
#   File "C:\Users\msy-o\Anaconda3\lib\urllib\request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\Users\msy-o\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     r = h.getresponse()
#   File "C:\Users\msy-o\Anaconda3\lib\http\client.py", line 1321, in getresponse
#     response.begin()
#   File "C:\Users\msy-o\Anaconda3\lib\http\client.py", line 296, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\msy-o\Anaconda3\lib\http\client.py", line 257, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\msy-o\Anaconda3\lib\socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\msy-o\Anaconda3\lib\ssl.py", line 1052, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\msy-o\Anaconda3\lib\ssl.py", line 911, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
# Error in fetching https://search.yahoo.co.jp/image/search?p=%E9%AC%BC%E6%BB%85%E3%81%AE%E5%88%83%2B%E6%BC%AB%E7%94%BB%2B%E7%82%AD%E6%B2%BB%E9%83%8E&ei=UTF-8&b=261
#
# fetched 140.gif
# fetched 141.jpg
# fetched 142.jpg
# fetched 143.jpg
# fetched 144.jpg
# fetched 145.jpg
# fetched 146.jpg
# fetched 147.jpg
# fetched 148.jpg
# fetched 149.jpg
# fetched 1410.jpg
# fetched 1411.jpg
# fetched 1412.jpg
# fetched 1413.jpg
# fetched 1414.jpg
# fetched 1415.jpg
# fetched 1416.jpg
# fetched 1417.jpg
# fetched 1418.jpg
# fetched 1419.jpg
# fetched 1420.jpg
# fetched 150.jpg
# fetched 151.gif
# fetched 152.jpg
# fetched 153.jpg
# fetched 154.jpg
# fetched 155.jpg
# fetched 156.jpg
# fetched 157.jpg
# fetched 158.jpg
# fetched 159.jpg
# fetched 1510.jpg
# fetched 1511.jpg
# fetched 1512.jpg
# fetched 1513.jpg
# fetched 1514.jpg
# fetched 1515.jpg
# fetched 1516.jpg
# fetched 1517.jpg
# fetched 1518.jpg
# fetched 1519.jpg
# fetched 1520.jpg
# fetched 160.jpg
# fetched 161.jpg
# fetched 162.jpg
# fetched 163.gif
# fetched 164.jpg
# fetched 165.jpg
# fetched 166.jpg
# fetched 167.jpg
# fetched 168.jpg
# fetched 169.jpg
# fetched 1610.jpg
# fetched 1611.jpg
# fetched 1612.jpg
# fetched 1613.jpg
# fetched 1614.jpg
# fetched 1615.jpg
# fetched 1616.jpg
# fetched 1617.jpg
# fetched 1618.jpg
# fetched 1619.jpg
# fetched 1620.jpg
# fetched 170.jpg
# fetched 171.gif
# fetched 172.jpg
# fetched 2916.jpg
# fetched 2917.jpg
# fetched 2918.jpg
# fetched 2919.jpg
# fetched 2920.jpg

# %%
# coding:utf-8

import requests
from bs4 import BeautifulSoup

url = 'https://animanch.com/archives/16861675.html'
# スクレイピングするユーザーエージェントを指定
headers = {'User-Agent':'Mozilla/5.0'}
soup = BeautifulSoup(requests.get(url,headers=headers).content,'lxml')
print(soup)
images = [] # 画像リストの空配列

for img in soup.find_all('img', class_="img", limit=5):
    # コンソールへスクレイピング対象の画像URLを表示。特段必須ではない
    print(img.get("src"))
    # imagesの空配列へsrcを登録
    images.append(img.get("src"))

# imagesからtargetに入れる
for target in images:
    re = requests.get(target)
    with open('./data/' + target.split('/')[-1], 'wb') as f: # imgフォルダに格納
      # .contentで画像データとして書き込む
      f.write(re.content)

# スクレイピング終了確認
print("画像保存が完了しました。")
# Out:
# class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-19">
# <div class="commentheader">
# <span class="commentnumber">19</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 06:35:09</span> <span class="commentid">ID:AzMTQ4MDc</span>
# </div>
# <div class="commentbody">まるで鬼滅が超大作アニメかのようだ…！<br/>
# </div>
# <div class="commentvote" id="vote19">
# <a class="comres-19" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_19"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-20">
# <div class="commentheader">
# <span class="commentnumber">20</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 08:22:30</span> <span class="commentid">ID:Q4Mjg5NzE</span>
# </div>
# <div class="commentbody">完璧すぎて…<br/>
# メイドインアビス以来の完璧さだ…<br/>
# 素晴らしい<br/>
# </div>
# <div class="commentvote" id="vote20">
# <a class="comres-20" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_20"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-21">
# <div class="commentheader">
# <span class="commentnumber">21</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 08:23:31</span> <span class="commentid">ID:U0MTg0NDY</span>
# </div>
# <div class="commentbody">冨岡ワープの後、外伝で警察にお縄にされると冨岡さんを想像すると草<br/>
# </div>
# <div class="commentvote" id="vote21">
# <a class="comres-21" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_21"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-26">
# <div class="commentheader">
# <span class="commentnumber">26</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 09:02:30</span> <span class="commentid">ID:k2NjQ2NDg</span>
# </div>
# <div class="commentbody">&gt;&gt;21<br/>
# …問題ない自分でなんとかする<br/>
# </div>
# <div class="commentvote" id="vote26">
# <a class="comres-26" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_26"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-23">
# <div class="commentheader">
# <span class="commentnumber">23</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 08:37:44</span> <span class="commentid">ID:A1MzcxMTY</span>
# </div>
# <div class="commentbody">今になって改めて見直すと<br/>
# ・成り立てとは言え鬼を片手で拘束する義勇さんやべぇ<br/>
# ・鬼を手刀で気絶させる義勇さんやべぇ<br/>
# <br/>
# 柱って強い<br/>
# </div>
# <div class="commentvote" id="vote23">
# <a class="comres-23" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_23"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-24">
# <div class="commentheader">
# <span class="commentnumber">24</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 08:51:43</span> <span class="commentid">ID:gzMzg0OTM</span>
# </div>
# <div class="commentbody">善逸の出番楽しみ<br/>
# こきう早く見てえなぁ<br/>
# </div>
# <div class="commentvote" id="vote24">
# <a class="comres-24" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_24"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-25">
# <div class="commentheader">
# <span class="commentnumber">25</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 08:57:07</span> <span class="commentid">ID:YzMTU0NTk</span>
# </div>
# <div class="commentbody">どこまでやるんだろ？<br/>
# 蜘蛛山やってパワハラやって終わり？<br/>
# </div>
# <div class="commentvote" id="vote25">
# <a class="comres-25" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_25"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-28">
# <div class="commentheader">
# <span class="commentnumber">28</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 09:16:08</span> <span class="commentid">ID:g1NTc3NjY</span>
# </div>
# <div class="commentbody">&gt;&gt;25<br/>
# 1クールで蜘蛛山やるのはきついけど2クールだと逆に余りそうな微妙なライン<br/>
# 今回見たいな原作補完多めで蜘蛛山＋αか無限列車までかどっちかと思われる<br/>
# 遊郭編は長いから流石に無理ぽ<br/>
# </div>
# <div class="commentvote" id="vote28">
# <a class="comres-28" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_28"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth2 commentwrap" id="comment-51">
# <div class="commentheader">
# <span class="commentnumber">51</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月08日 14:10:17</span> <span class="commentid">ID:czNDkyMDg</span>
# </div>
# <div class="commentbody">&gt;&gt;28<br/>
# 補完入れながら蜘蛛山くらいがベストっぽいよね。OPに柱揃ってるから柱会議と蝶屋敷やって二期へ、みたいだったら個人的に理想ですが…<br/>
# </div>
# <div class="commentvote" id="vote51">
# <a class="comres-51" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_51"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-31">
# <div class="commentheader">
# <span class="commentnumber">31</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 10:44:07</span> <span class="commentid">ID:UyMTg1NDU</span>
# </div>
# <div class="commentbody">脱税で貯めた金で作るアニメは面白いか？<br/>
# </div>
# <div class="commentvote" id="vote31">
# <a class="comres-31" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_31"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-32">
# <div class="commentheader">
# <span class="commentnumber">32</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 10:57:08</span> <span class="commentid">ID:c0NjQyMDc</span>
# </div>
# <div class="commentbody">&gt;&gt;31<br/>
# とても面白かったです<br/>
# </div>
# <div class="commentvote" id="vote32">
# <a class="comres-32" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_32"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-42">
# <div class="commentheader">
# <span class="commentnumber">42</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 13:29:55</span> <span class="commentid">ID:g1NTc3NjY</span>
# </div>
# <div class="commentbody">&gt;&gt;31<br/>
# アニメを作る側と楽しむ側は別なんだからコピペにしたってその物言いはおかしいやろ<br/>
# </div>
# <div class="commentvote" id="vote42">
# <a class="comres-42" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_42"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-48">
# <div class="commentheader">
# <span class="commentnumber">48</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 17:12:41</span> <span class="commentid">ID:Q2Njc4MDQ</span>
# </div>
# <div class="commentbody">&gt;&gt;31<br/>
# Fateの会社なんだからそら脱税ぐらいする<br/>
# </div>
# <div class="commentvote" id="vote48">
# <a class="comres-48" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_48"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-33">
# <div class="commentheader">
# <span class="commentnumber">33</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 11:17:22</span> <span class="commentid">ID:E5NTUyOTc</span>
# </div>
# <div class="commentbody">浮世絵みたいなエフェクトの質感がすごいな<br/>
# </div>
# <div class="commentvote" id="vote33">
# <a class="comres-33" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_33"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-34">
# <div class="commentheader">
# <span class="commentnumber">34</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 11:20:17</span> <span class="commentid">ID:czNzcwMTM</span>
# </div>
# <div class="commentbody">すんげー気合い入ってる、嬉しいなぁ。<br/>
# でも悲しいなぁ・・・<br/>
# </div>
# <div class="commentvote" id="vote34">
# <a class="comres-34" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_34"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-35">
# <div class="commentheader">
# <span class="commentnumber">35</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 11:20:37</span> <span class="commentid">ID:I5MDA3MTU</span>
# </div>
# <div class="commentbody">生殺与奪のところ誰一人正確に言えてなくて笑う<br/>
# </div>
# <div class="commentvote" id="vote35">
# <a class="comres-35" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_35"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-36">
# <div class="commentheader">
# <span class="commentnumber">36</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 11:22:10</span> <span class="commentid">ID:I5NDUzNTM</span>
# </div>
# <div class="commentbody">アカザが多過ぎて笑うわ(笑)<br/>
# </div>
# <div class="commentvote" id="vote36">
# <a class="comres-36" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_36"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-37">
# <div class="commentheader">
# <span class="commentnumber">37</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 12:50:15</span> <span class="commentid">ID:I3NTgxMTE</span>
# </div>
# <div class="commentbody">ＴＶアニメでこの作り込みって馬鹿だろ（褒め言葉）<br/>
# ufoの現場スタッフはほんと身体に気を付けてくれそして脱税した連中はお前らだけが責を負え<br/>
# </div>
# <div class="commentvote" id="vote37">
# <a class="comres-37" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_37"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-38">
# <div class="commentheader">
# <span class="commentnumber">38</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 12:50:29</span> <span class="commentid">ID:Y3NTU0NzU</span>
# </div>
# <div class="commentbody">(分かるよ)で錆兎の側の羽織映すのずるいですよ義勇さん<br/>
# </div>
# <div class="commentvote" id="vote38">
# <a class="comres-38" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_38"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-39">
# <div class="commentheader">
# <span class="commentnumber">39</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 13:07:22</span> <span class="commentid">ID:AwNjM2MDI</span>
# </div>
# <div class="commentbody">初見だけど面白かった<br/>
# 原作気になるけどギャグ多い感じなのか？<br/>
# </div>
# <div class="commentvote" id="vote39">
# <a class="comres-39" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_39"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-41">
# <div class="commentheader">
# <span class="commentnumber">41</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 13:29:34</span> <span class="commentid">ID:M2Nzc3MjI</span>
# </div>
# <div class="commentbody">&gt;&gt;39<br/>
# 日常回や新章の導入はギャグ多いね<br/>
# あとシリアスな笑いというか真面目な部分でもネタにされる所はある<br/>
# とはいえご覧の通り基本的にクッソ重くてシリアスなんでそういう笑いがないと辛いのよ…<br/>
# </div>
# <div class="commentvote" id="vote41">
# <a class="comres-41" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_41"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-43">
# <div class="commentheader">
# <span class="commentnumber">43</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 13:30:43</span> <span class="commentid">ID:g1NTc3NjY</span>
# </div>
# <div class="commentbody">&gt;&gt;39<br/>
# 1話はドシリアスだったけど2話以降はゆるいノリ増えてくるで<br/>
# </div>
# <div class="commentvote" id="vote43">
# <a class="comres-43" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_43"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-45">
# <div class="commentheader">
# <span class="commentnumber">45</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 16:15:07</span> <span class="commentid">ID:E2MDMxMTA</span>
# </div>
# <div class="commentbody">掴みは完璧だと思うわ<br/>
# 原作未読だけど視聴継続<br/>
# </div>
# <div class="commentvote" id="vote45">
# <a class="comres-45" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_45"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-49">
# <div class="commentheader">
# <span class="commentnumber">49</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月07日 18:53:54</span> <span class="commentid">ID:IzNDY1OTU</span>
# </div>
# <div class="commentbody">3、4話で原作通りがっつり修行するのでせっかちな未読が離れるかもしれない<br/>
# 5話で年号<br/>
# </div>
# <div class="commentvote" id="vote49">
# <a class="comres-49" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_49"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="depth1 commentwrap" id="comment-52">
# <div class="commentheader">
# <span class="commentnumber">52</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月08日 14:11:19</span> <span class="commentid">ID:czNDkyMDg</span>
# </div>
# <div class="commentbody">&gt;&gt;49<br/>
# 3、4話を一話で纏める可能性も微レ存<br/>
# </div>
# <div class="commentvote" id="vote52">
# <a class="comres-52" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_52"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-55">
# <div class="commentheader">
# <span class="commentnumber">55</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月08日 15:00:09</span> <span class="commentid">ID:k2MDU5Njg</span>
# </div>
# <div class="commentbody">クオリティ高すぎて草<br/>
# </div>
# <div class="commentvote" id="vote55">
# <a class="comres-55" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_55"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div class="commentwrap" id="comment-56">
# <div class="commentheader">
# <span class="commentnumber">56</span>. <span class="commentname">名無しのあにまんch</span> <span class="commentdate">2019年04月13日 19:55:40</span> <span class="commentid">ID:I4ODY3MTM</span>
# </div>
# <div class="commentbody">しんどいけど魅入る<br/>
# </div>
# <div class="commentvote" id="vote56">
# <a class="comres-56" name="#commentform"><i class="fa fa-reply"></i></a>
# <button class="comvote_yes" id="comyes_56"><i class="fa fa-heart-o"></i></button><span class="votecount">0</span>
# </div>
# </div> <div id="commentform">
# <form action="https://animanch.com/wp/wp-comments-post.php" id="comment_form" method="post">
# <label for="name" hidden="">名前</label>
# <input class="form-name" id="name" name="author" placeholder="名前を入力(空欄可)" type="text" value=""/>
# <label for="comment" hidden="">本文</label>
# <textarea id="comment" name="comment" placeholder="本文を入力" required="required"></textarea>
# <input name="submit" type="submit" value="送信する"/>
# <input id="comment_post_ID" name="comment_post_ID" type="hidden" value="16145"/>
# <input id="comment_parent" name="comment_parent" type="hidden" value="0"/>
# </form>
# <div class="abox"><script src="//js.gsspcln.jp/t/350/558/a1350558.js" type="text/javascript"></script></div>
# </div>
# <p id="comnote">このサイトはCPネタやCPギャグがあるので苦手な方はブラウザパックお願いします<br/>
# また荒らし、誹謗中傷、露骨なキャラdis、他サイトの名出し、性別差別、レッテル貼り、明らかな対立煽りなどの悪質なコメントは削除します<br/>
# <br/>
# 反論や批判はマイルドに　マジで…<br/>
# 荒らしは無視でお願いします<br/>
# 現在削除用メールフォーム作成中<br/></p>
# </div> </main>
# <div id="fixbtns"><p class="totop navibtn"><a href="#headerinner" title="ページトップへ"></a></p>
# <p class="navibtn nextpage"><a href="https://animanch.com/archives/16862777.html" title="【感想】 ぼくたちは勉強ができない 1話 初っ端怠慢先生！ 髪色が原色で気になるが文系と理系がかわいくてニヤニヤが止まらない　期待できそうだ【ぼく勉】"></a></p><p class="navibtn prevpage"><a href="https://animanch.com/archives/16780747.html" title="メイドインアビスのアニメ面白かったのにTVアニメ2期できないのかな？"></a></p><p class="comwrite navibtn"><a href="#commentarea" title="コメントを読む"></a></p><p class="comview navibtn"><a href="#commentform" title="コメントを書く"></a></p></div></div>
# <footer>
# <a class="copy" href="https://animanch.com">©あにまんchまとめ</a>
# </footer>
# <div id="fb-root"></div>
# <script src="https://animanch.com/wp/wp-content/themes/animan/commons/fixBox.min.js"></script>
# <script>var commentMode = "pc";</script>
# <script>
# (function(w,d){
# 	var s, e = d.getElementsByTagName("script")[0],
# 	a = function (u, i) {
# 		if (!d.getElementById(i)) {
# 			s = d.createElement("script");
# 			s.src = u;
# 			if (i) {s.id = i;}
# 			e.parentNode.insertBefore(s, e);
# 		}
# 	};
# 	a("//b.st-hatena.com/js/bookmark_button_wo_al.js");
# 	a("//platform.twitter.com/widgets.js", "twitter-wjs");
# })(this, document);
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-60190807-2"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-60190807-2');
# </script>
# <div id="g_floating_area1" style="display:none;top:0px;z-index:10000000000;right:50%;">
# <!--  ad tags Size: 160x600 ZoneId:1425972-->
# <script src="https://js.gsspcln.jp/t/425/972/a1425972.js" type="text/javascript"></script>
# </div>
# <div id="g_floating_area2" style="display:none;top:0px;z-index:10000000000;left:50%;">
# <script type="text/javascript">
# var microadCompass = microadCompass || {};
# microadCompass.queue = microadCompass.queue || [];
# </script>
# <script async="" charset="UTF-8" onload="new microadCompass.AdInitializer().initialize();" src="//j.microad.net/js/compass.js" type="text/javascript"></script>
# <div id="fbd086dee3c0cb40ccc3a17a98135d88">
# <script type="text/javascript">
# microadCompass.queue.push({
# "spot": "fbd086dee3c0cb40ccc3a17a98135d88"
# });
# </script>
# </div>
# </div>
# <script type="text/javascript">
# window.__gnsj = {
#     "contents_width": 1122,
#     "extra_margin"  : 1,
#     "top_pos"       : 0,
#     "footer_pos"    : 0
# };
# </script>
# <script src="//js.gsspcln.jp/sdk/l/geniee_sjv5.js" type="text/javascript"></script>
# <div id="right_fix" style="position:fixed;right:0;bottom:0">
# <!--  ad tags Size: 300x250 ZoneId:1385848-->
# <script src="https://js.gsspcln.jp/t/385/848/a1385848.js" type="text/javascript"></script>
# </div><script>
# var comRating = {
# 	"vote_bad2":-999,
# 	"vote_bad1":-10,
# 	"vote_normal":-5,
# 	"vote_good1":7,
# 	"vote_good2":16,
# 	"vote_good3":31,
# 	"vote_good4":41,
# 	"vote_good5":61,
# 	"vote_good6":999
# };
# </script><p id="popup"></p>
# <script src="https://animanch.com/wp/wp-content/themes/animan/commons/comment.min.js"></script>
# <link href="https://animanch.com/wp/wp-content/themes/animan/commons/comment.css" rel="stylesheet" type="text/css"/>
# <link href="https://animanch.com/wp/wp-content/themes/animan/commons/twitter.css" rel="stylesheet" type="text/css"/>
# </body>
# </html>
# 画像保存が完了しました。
